# %%
import pandas as pd

# %%
datafile = 'data/beatles-diskography.csv'

# %%
def parse_file(datafile):
    data = []
    with open(datafile, "r") as f:
        firstline = True
        for line in f:
            if firstline:
                firstline = False
                continue
            else:
                parsed_line = [el.strip() for el in line.split(',')]
                line_dict = {}
                line_dict['Title'] = parsed_line[0]
                line_dict['Released'] = parsed_line[1]
                line_dict['Label'] = parsed_line[2]
                line_dict['UK Chart Position'] = parsed_line[3]
                line_dict['US Chart Position'] = parsed_line[4]
                line_dict['BPI Certification'] = parsed_line[5]
                line_dict['RIAA Certification'] = parsed_line[6]
                if len(data) < 10:
                    data.append(line_dict)
    return data

# %%
parse_file(datafile)
# Out:
# [{'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Platinum',
#   'Released': '22 March 1963',
#   'Title': 'Please Please Me',
#   'UK Chart Position': '1',
#   'US Chart Position': '—'},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Gold',
#   'Released': '22 November 1963',
#   'Title': 'With the Beatles',
#   'UK Chart Position': '1',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '25 November 1963',
#   'Title': 'Beatlemania! With the Beatles',
#   'UK Chart Position': '—',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'Vee-Jay(US)',
#   'RIAA Certification': '',
#   'Released': '10 January 1964',
#   'Title': 'Introducing... The Beatles',
#   'UK Chart Position': '—',
#   'US Chart Position': '2'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '5xPlatinum',
#   'Released': '20 January 1964',
#   'Title': 'Meet the Beatles!',
#   'UK Chart Position': '—',
#   'US Chart Position': '1'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '3 February 1964',
#   'Title': 'Twist and Shout',
#   'UK Chart Position': '—',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '2xPlatinum',
#   'Released': '10 April 1964',
#   'Title': "The Beatles' Second Album",
#   'UK Chart Position': '—',
#   'US Chart Position': '1'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '11 May 1964',
#   'Title': "The Beatles' Long Tall Sally",
#   'UK Chart Position': '—',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'United Artists(US)[C]',
#   'RIAA Certification': '4xPlatinum',
#   'Released': '26 June 1964',
#   'Title': "A Hard Day's Night",
#   'UK Chart Position': '—',
#   'US Chart Position': '1'},
#  {'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': '',
#   'Released': '10 July 1964',
#   'Title': '',
#   'UK Chart Position': '1',
#   'US Chart Position': '—'}]

# %%
def parse_file_ans(datafile):
    data = []
    with open(datafile, 'r') as f:
        header = f.readline().split(',')
        counter = 0
        for line in f:
            if counter == 10:
                break
            fields = line.split(',')
            dict_entry = {}
            for i, value in enumerate(fields):
                dict_entry[header[i].strip()] = value.strip()
            data.append(dict_entry)
            counter +=1
    return data

# %%
parse_file_ans(datafile)
# Out:
# [{'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Platinum',
#   'Released': '22 March 1963',
#   'Title': 'Please Please Me',
#   'UK Chart Position': '1',
#   'US Chart Position': '—'},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Gold',
#   'Released': '22 November 1963',
#   'Title': 'With the Beatles',
#   'UK Chart Position': '1',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '25 November 1963',
#   'Title': 'Beatlemania! With the Beatles',
#   'UK Chart Position': '—',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'Vee-Jay(US)',
#   'RIAA Certification': '',
#   'Released': '10 January 1964',
#   'Title': 'Introducing... The Beatles',
#   'UK Chart Position': '—',
#   'US Chart Position': '2'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '5xPlatinum',
#   'Released': '20 January 1964',
#   'Title': 'Meet the Beatles!',
#   'UK Chart Position': '—',
#   'US Chart Position': '1'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '3 February 1964',
#   'Title': 'Twist and Shout',
#   'UK Chart Position': '—',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
#   'RIAA Certification': '2xPlatinum',
#   'Released': '10 April 1964',
#   'Title': "The Beatles' Second Album",
#   'UK Chart Position': '—',
#   'US Chart Position': '1'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '11 May 1964',
#   'Title': "The Beatles' Long Tall Sally",
#   'UK Chart Position': '—',
#   'US Chart Position': '—'},
#  {'BPI Certification': '',
#   'Label': 'United Artists(US)[C]',
#   'RIAA Certification': '4xPlatinum',
#   'Released': '26 June 1964',
#   'Title': "A Hard Day's Night",
#   'UK Chart Position': '—',
#   'US Chart Position': '1'},
#  {'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': '',
#   'Released': '10 July 1964',
#   'Title': '',
#   'UK Chart Position': '1',
#   'US Chart Position': '—'}]

# %%
import xlrd
import numpy as np

# %%
def xlrd_example(datafile):
    workbook = xlrd.open_workbook(datafile) # Open a workbook
    sheet = workbook.sheet_by_index(0) # Specify sheet to work with. xlrd uses zero-based indexing.
    
    # List-based comprehension: 
    # Looping through rows and columns 
    # and reading that data into a Python list
    data = [[sheet.cell_value(r, col) 
                for col in range(sheet.ncols)] 
                    for r in range(sheet.nrows)]
    
    print("\nList Comprehension")
    print("data[3][2]:",) 
    # Print Row 3 Col 2
    print(data[3][2])

    print("\nCells in a nested loop:" )   
    for row in range(sheet.nrows):
        for col in range(sheet.ncols):
            if row == 50:
                # Print all values in that row, one col at a time
                print(sheet.cell_value(row, col),)


    ### other useful methods:
    print("\nROWS, COLUMNS, and CELLS:")
    print("Number of rows in the sheet:", )
    print(sheet.nrows)
    print("Type of data in cell (row 3, col 2):",) 
    print(sheet.cell_type(3, 2))
    print("Value in cell (row 3, col 2):",) 
    print(sheet.cell_value(3, 2))
    print("Get a slice of values in column 3, from rows 1-3:")
    print(sheet.col_values(3, start_rowx=1, end_rowx=4)) # Upper bound non-inclusive

    print("\nDATES:")
    #Prev dates in Excel represented as floating points
    print("Type of data in cell (row 1, col 0):",) 
    print(sheet.cell_type(1, 0))
    exceltime = sheet.cell_value(1, 0)
    print("Time in Excel format:",) 
    print(exceltime)
    print("Convert time to a Python datetime tuple, from the Excel float:",)
    print(xlrd.xldate_as_tuple(exceltime, 0)) # Helps us work with date in Python

xlrd_example('2013_ERCOT_Hourly_Load_Data.xls')
# Out:
# List Comprehension
# data[3][2]:
# 1036.0886969999988
#
# Cells in a nested loop:
# 41277.083333333336
# 9238.737309999968
# 1438.2052799999994
# 1565.4428559999976
# 916.7083480000003
# 14010.903488000036
# 3027.9833399999993
# 6165.211119000006
# 1157.7416630000007
# 37520.93340400001
#
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet:
# 7296
# Type of data in cell (row 3, col 2):
# 2
# Value in cell (row 3, col 2):
# 1036.0886969999988
# Get a slice of values in column 3, from rows 1-3:
# [1411.7505669999982, 1403.4722870000019, 1395.053150000001]
#
# DATES:
# Type of data in cell (row 1, col 0):
# 3
# Time in Excel format:
# 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float:
# (2013, 1, 1, 1, 0, 0)

# %%
datafile = "data/2013_ERCOT_Hourly_Load_Data.xls"

def parse_file(datafile):
    workbook = xlrd.open_workbook(datafile) # Open a workbook
    sheet = workbook.sheet_by_index(0) # Specify sheet to work with. xlrd uses zero-based indexing.
    
    # List-based comprehension: 
    # Looping through rows and columns 
    # and reading that data into a Python list
    file_data = [[sheet.cell_value(r, col) 
                for col in range(sheet.ncols)] 
                    for r in range(sheet.nrows)]
    
    """
    - read the provided Excel file
    - find and return the min, max and average values for the COAST region
    - find and return the time value for the min and max entries
    - the time values should be returned as Python tuples
    """
    
    
    coast_values = sheet.col_values(1, start_rowx=1, end_rowx=sheet.nrows)
    
    coast_values_np = np.array(coast_values)
    
    max_val = max(coast_values)
    min_val = min(coast_values)
    avg_val = coast_values_np.mean() # Also: sum(coast_values) / float(len(coast_values))
    
    max_pos = coast_values.index(max_val) + 1
    min_pos = coast_values.index(min_val) + 1
    
    max_time = sheet.cell_value(max_pos,0)
    real_max_time = xlrd.xldate_as_tuple(max_time, 0)
    min_time = sheet.cell_value(min_pos,0)
    real_min_time = xlrd.xldate_as_tuple(min_time, 0)
    
    data = {
            'maxtime': real_max_time,
            'maxvalue': max_val,
            'mintime': real_min_time,
            'minvalue': min_val,
            'avgcoast': avg_val
    }    
    
    print(data)

def test():
    open_zip(datafile)
    data = parse_file(datafile)

    assert data['maxtime'] == (2013, 8, 13, 17, 0, 0)
    assert round(data['maxvalue'], 10) == round(18779.02551, 10)
    
data = parse_file(datafile)
# Out:
# {'mintime': (2013, 2, 3, 4, 0, 0), 'avgcoast': 10976.933460679784, 'maxvalue': 18779.025510000003, 'maxtime': (2013, 8, 13, 17, 0, 0), 'minvalue': 6602.113898999982}

# %% [markdown]
# ### xlrd Functions and Methods
# - .index(value)
# - xlrd.xldate_as_tuple(variable,0)

# %% [markdown]
# ## Problem Set
# ### 1. Using CSV Module

# %%
ps1_data_path = "data/nrel-solar-wind-energy-subset.csv"
ps1_data = pd.read_csv(ps1_data_path)

# %%
ps1_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                745090  \
# Date (MM/DD/YYYY) Time (HH:MM) ETR (W/m^2) ETRN (W/m^2) GHI (W/m^2) GHI source GHI uncert (%) DNI (W/m^2) DNI source DNI uncert (%) DHI (W/m^2) DHI source DHI uncert (%) GH illum (lx) GH illum source Global illum uncert (%) DN illum (lx) DN illum source DN illum uncert (%) DH illum (lx) DH illum source DH illum uncert (%) Zenith lum (cd/m^2) Zenith lum source Zenith lum uncert (%) TotCld (tenths) TotCld source TotCld uncert (code) OpqCld (tenths) OpqCld source OpqCld uncert (code) Dry-bulb (C) Dry-bulb source Dry-bulb uncert (code) Dew-point (C) Dew-point source Dew-point uncert (code) RHum (%) RHum source RHum uncert (code) Pressure (mbar) Pressure source Pressure uncert (code) Wdir (degrees) Wdir source Wdir uncert (code) Wspd (m/s) Wspd source Wspd uncert (code) Hvis (m) Hvis source Hvis uncert (code) CeilHgt (m) CeilHgt source CeilHgt uncert (code) Pwat (cm) Pwat source Pwat uncert (code) AOD (unitless) AOD source AOD uncert (code)  Alb (unitless)
# 01/01/2005        01:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     3               E             9                    3               E             9                    8.0          A               7                      6.0           A                7                       87       A           7                  1013            A               7                      150            A           7                  2.1        A           7                  16100    A           7                  77777       A              7                     1.1       E           8                  0.099          F          8                           0.160
#                   02:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1013            A               7                      0              A           7                  0.0        A           7                  12900    A           7                  930         A              7                     1.1       E           8                  0.099          F          8                           0.160
#                   03:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     8               E             9                    8               E             9                    7.0          A               7                      6.0           A                7                       93       A           7                  1013            A               7                      120            A           7                  2.1        A           7                  16100    A           7                  2100        A              7                     1.1       E           8                  0.099          F          8                           0.160
#                   04:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1014            A               7                      160            A           7                  2.6        A           7                  16100    A           7                  1500        A              7                     1.1       E           8                  0.099          F          8                           0.160
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       MOUNTAIN VIEW MOFFETT FLD NAS  \
# Date (MM/DD/YYYY) Time (HH:MM) ETR (W/m^2) ETRN (W/m^2) GHI (W/m^2) GHI source GHI uncert (%) DNI (W/m^2) DNI source DNI uncert (%) DHI (W/m^2) DHI source DHI uncert (%) GH illum (lx) GH illum source Global illum uncert (%) DN illum (lx) DN illum source DN illum uncert (%) DH illum (lx) DH illum source DH illum uncert (%) Zenith lum (cd/m^2) Zenith lum source Zenith lum uncert (%) TotCld (tenths) TotCld source TotCld uncert (code) OpqCld (tenths) OpqCld source OpqCld uncert (code) Dry-bulb (C) Dry-bulb source Dry-bulb uncert (code) Dew-point (C) Dew-point source Dew-point uncert (code) RHum (%) RHum source RHum uncert (code) Pressure (mbar) Pressure source Pressure uncert (code) Wdir (degrees) Wdir source Wdir uncert (code) Wspd (m/s) Wspd source Wspd uncert (code) Hvis (m) Hvis source Hvis uncert (code) CeilHgt (m) CeilHgt source CeilHgt uncert (code) Pwat (cm) Pwat source Pwat uncert (code) AOD (unitless) AOD source AOD uncert (code)                    Alb source
# 01/01/2005        01:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     3               E             9                    3               E             9                    8.0          A               7                      6.0           A                7                       87       A           7                  1013            A               7                      150            A           7                  2.1        A           7                  16100    A           7                  77777       A              7                     1.1       E           8                  0.099          F          8                                             F
#                   02:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1013            A               7                      0              A           7                  0.0        A           7                  12900    A           7                  930         A              7                     1.1       E           8                  0.099          F          8                                             F
#                   03:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     8               E             9                    8               E             9                    7.0          A               7                      6.0           A                7                       93       A           7                  1013            A               7                      120            A           7                  2.1        A           7                  16100    A           7                  2100        A              7                     1.1       E           8                  0.099          F          8                                             F
#                   04:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1014            A               7                      160            A           7                  2.6        A           7                  16100    A           7                  1500        A              7                     1.1       E           8                  0.099          F          8                                             F
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       CA  \
# Date (MM/DD/YYYY) Time (HH:MM) ETR (W/m^2) ETRN (W/m^2) GHI (W/m^2) GHI source GHI uncert (%) DNI (W/m^2) DNI source DNI uncert (%) DHI (W/m^2) DHI source DHI uncert (%) GH illum (lx) GH illum source Global illum uncert (%) DN illum (lx) DN illum source DN illum uncert (%) DH illum (lx) DH illum source DH illum uncert (%) Zenith lum (cd/m^2) Zenith lum source Zenith lum uncert (%) TotCld (tenths) TotCld source TotCld uncert (code) OpqCld (tenths) OpqCld source OpqCld uncert (code) Dry-bulb (C) Dry-bulb source Dry-bulb uncert (code) Dew-point (C) Dew-point source Dew-point uncert (code) RHum (%) RHum source RHum uncert (code) Pressure (mbar) Pressure source Pressure uncert (code) Wdir (degrees) Wdir source Wdir uncert (code) Wspd (m/s) Wspd source Wspd uncert (code) Hvis (m) Hvis source Hvis uncert (code) CeilHgt (m) CeilHgt source CeilHgt uncert (code) Pwat (cm) Pwat source Pwat uncert (code) AOD (unitless) AOD source AOD uncert (code)  Alb uncert (code)
# 01/01/2005        01:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     3               E             9                    3               E             9                    8.0          A               7                      6.0           A                7                       87       A           7                  1013            A               7                      150            A           7                  2.1        A           7                  16100    A           7                  77777       A              7                     1.1       E           8                  0.099          F          8                                  8
#                   02:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1013            A               7                      0              A           7                  0.0        A           7                  12900    A           7                  930         A              7                     1.1       E           8                  0.099          F          8                                  8
#                   03:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     8               E             9                    8               E             9                    7.0          A               7                      6.0           A                7                       93       A           7                  1013            A               7                      120            A           7                  2.1        A           7                  16100    A           7                  2100        A              7                     1.1       E           8                  0.099          F          8                                  8
#                   04:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1014            A               7                      160            A           7                  2.6        A           7                  16100    A           7                  1500        A              7                     1.1       E           8                  0.099          F          8                                  8
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      -8.0  \
# Date (MM/DD/YYYY) Time (HH:MM) ETR (W/m^2) ETRN (W/m^2) GHI (W/m^2) GHI source GHI uncert (%) DNI (W/m^2) DNI source DNI uncert (%) DHI (W/m^2) DHI source DHI uncert (%) GH illum (lx) GH illum source Global illum uncert (%) DN illum (lx) DN illum source DN illum uncert (%) DH illum (lx) DH illum source DH illum uncert (%) Zenith lum (cd/m^2) Zenith lum source Zenith lum uncert (%) TotCld (tenths) TotCld source TotCld uncert (code) OpqCld (tenths) OpqCld source OpqCld uncert (code) Dry-bulb (C) Dry-bulb source Dry-bulb uncert (code) Dew-point (C) Dew-point source Dew-point uncert (code) RHum (%) RHum source RHum uncert (code) Pressure (mbar) Pressure source Pressure uncert (code) Wdir (degrees) Wdir source Wdir uncert (code) Wspd (m/s) Wspd source Wspd uncert (code) Hvis (m) Hvis source Hvis uncert (code) CeilHgt (m) CeilHgt source CeilHgt uncert (code) Pwat (cm) Pwat source Pwat uncert (code) AOD (unitless) AOD source AOD uncert (code)  Lprecip depth (mm)
# 01/01/2005        01:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     3               E             9                    3               E             9                    8.0          A               7                      6.0           A                7                       87       A           7                  1013            A               7                      150            A           7                  2.1        A           7                  16100    A           7                  77777       A              7                     1.1       E           8                  0.099          F          8                                   0
#                   02:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1013            A               7                      0              A           7                  0.0        A           7                  12900    A           7                  930         A              7                     1.1       E           8                  0.099          F          8                                   0
#                   03:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     8               E             9                    8               E             9                    7.0          A               7                      6.0           A                7                       93       A           7                  1013            A               7                      120            A           7                  2.1        A           7                  16100    A           7                  2100        A              7                     1.1       E           8                  0.099          F          8                                   0
#                   04:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1014            A               7                      160            A           7                  2.6        A           7                  16100    A           7                  1500        A              7                     1.1       E           8                  0.099          F          8                                   0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       37.400  \
# Date (MM/DD/YYYY) Time (HH:MM) ETR (W/m^2) ETRN (W/m^2) GHI (W/m^2) GHI source GHI uncert (%) DNI (W/m^2) DNI source DNI uncert (%) DHI (W/m^2) DHI source DHI uncert (%) GH illum (lx) GH illum source Global illum uncert (%) DN illum (lx) DN illum source DN illum uncert (%) DH illum (lx) DH illum source DH illum uncert (%) Zenith lum (cd/m^2) Zenith lum source Zenith lum uncert (%) TotCld (tenths) TotCld source TotCld uncert (code) OpqCld (tenths) OpqCld source OpqCld uncert (code) Dry-bulb (C) Dry-bulb source Dry-bulb uncert (code) Dew-point (C) Dew-point source Dew-point uncert (code) RHum (%) RHum source RHum uncert (code) Pressure (mbar) Pressure source Pressure uncert (code) Wdir (degrees) Wdir source Wdir uncert (code) Wspd (m/s) Wspd source Wspd uncert (code) Hvis (m) Hvis source Hvis uncert (code) CeilHgt (m) CeilHgt source CeilHgt uncert (code) Pwat (cm) Pwat source Pwat uncert (code) AOD (unitless) AOD source AOD uncert (code)  Lprecip quantity (hr)
# 01/01/2005        01:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     3               E             9                    3               E             9                    8.0          A               7                      6.0           A                7                       87       A           7                  1013            A               7                      150            A           7                  2.1        A           7                  16100    A           7                  77777       A              7                     1.1       E           8                  0.099          F          8                                      1
#                   02:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1013            A               7                      0              A           7                  0.0        A           7                  12900    A           7                  930         A              7                     1.1       E           8                  0.099          F          8                                      1
#                   03:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     8               E             9                    8               E             9                    7.0          A               7                      6.0           A                7                       93       A           7                  1013            A               7                      120            A           7                  2.1        A           7                  16100    A           7                  2100        A              7                     1.1       E           8                  0.099          F          8                                      1
#                   04:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1014            A               7                      160            A           7                  2.6        A           7                  16100    A           7                  1500        A              7                     1.1       E           8                  0.099          F          8                                      1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              -122.050  \
# Date (MM/DD/YYYY) Time (HH:MM) ETR (W/m^2) ETRN (W/m^2) GHI (W/m^2) GHI source GHI uncert (%) DNI (W/m^2) DNI source DNI uncert (%) DHI (W/m^2) DHI source DHI uncert (%) GH illum (lx) GH illum source Global illum uncert (%) DN illum (lx) DN illum source DN illum uncert (%) DH illum (lx) DH illum source DH illum uncert (%) Zenith lum (cd/m^2) Zenith lum source Zenith lum uncert (%) TotCld (tenths) TotCld source TotCld uncert (code) OpqCld (tenths) OpqCld source OpqCld uncert (code) Dry-bulb (C) Dry-bulb source Dry-bulb uncert (code) Dew-point (C) Dew-point source Dew-point uncert (code) RHum (%) RHum source RHum uncert (code) Pressure (mbar) Pressure source Pressure uncert (code) Wdir (degrees) Wdir source Wdir uncert (code) Wspd (m/s) Wspd source Wspd uncert (code) Hvis (m) Hvis source Hvis uncert (code) CeilHgt (m) CeilHgt source CeilHgt uncert (code) Pwat (cm) Pwat source Pwat uncert (code) AOD (unitless) AOD source AOD uncert (code)  Lprecip source
# 01/01/2005        01:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     3               E             9                    3               E             9                    8.0          A               7                      6.0           A                7                       87       A           7                  1013            A               7                      150            A           7                  2.1        A           7                  16100    A           7                  77777       A              7                     1.1       E           8                  0.099          F          8                               A
#                   02:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1013            A               7                      0              A           7                  0.0        A           7                  12900    A           7                  930         A              7                     1.1       E           8                  0.099          F          8                               A
#                   03:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     8               E             9                    8               E             9                    7.0          A               7                      6.0           A                7                       93       A           7                  1013            A               7                      120            A           7                  2.1        A           7                  16100    A           7                  2100        A              7                     1.1       E           8                  0.099          F          8                               A
#                   04:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1014            A               7                      160            A           7                  2.6        A           7                  16100    A           7                  1500        A              7                     1.1       E           8                  0.099          F          8                               A
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           12
# Date (MM/DD/YYYY) Time (HH:MM) ETR (W/m^2) ETRN (W/m^2) GHI (W/m^2) GHI source GHI uncert (%) DNI (W/m^2) DNI source DNI uncert (%) DHI (W/m^2) DHI source DHI uncert (%) GH illum (lx) GH illum source Global illum uncert (%) DN illum (lx) DN illum source DN illum uncert (%) DH illum (lx) DH illum source DH illum uncert (%) Zenith lum (cd/m^2) Zenith lum source Zenith lum uncert (%) TotCld (tenths) TotCld source TotCld uncert (code) OpqCld (tenths) OpqCld source OpqCld uncert (code) Dry-bulb (C) Dry-bulb source Dry-bulb uncert (code) Dew-point (C) Dew-point source Dew-point uncert (code) RHum (%) RHum source RHum uncert (code) Pressure (mbar) Pressure source Pressure uncert (code) Wdir (degrees) Wdir source Wdir uncert (code) Wspd (m/s) Wspd source Wspd uncert (code) Hvis (m) Hvis source Hvis uncert (code) CeilHgt (m) CeilHgt source CeilHgt uncert (code) Pwat (cm) Pwat source Pwat uncert (code) AOD (unitless) AOD source AOD uncert (code)  Lprecip uncert (code)
# 01/01/2005        01:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     3               E             9                    3               E             9                    8.0          A               7                      6.0           A                7                       87       A           7                  1013            A               7                      150            A           7                  2.1        A           7                  16100    A           7                  77777       A              7                     1.1       E           8                  0.099          F          8                                      7
#                   02:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1013            A               7                      0              A           7                  0.0        A           7                  12900    A           7                  930         A              7                     1.1       E           8                  0.099          F          8                                      7
#                   03:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     8               E             9                    8               E             9                    7.0          A               7                      6.0           A                7                       93       A           7                  1013            A               7                      120            A           7                  2.1        A           7                  16100    A           7                  2100        A              7                     1.1       E           8                  0.099          F          8                                      7
#                   04:00        0           0            0           2          0              0           2          0              0           2          0              0             2               0                       0             2               0                   0             2               0                   0                   2                 0                     10              E             9                    10              E             9                    8.0          A               7                      7.0           A                7                       93       A           7                  1014            A               7                      160            A           7                  2.6        A           7                  16100    A           7                  1500        A              7                     1.1       E           8                  0.099          F          8                                      7

# %%
#!/usr/bin/env python
"""
Your task is to process the supplied file and use the csv module to extract data from it.
The data comes from NREL (National Renewable Energy Laboratory) website. Each file
contains information from one meteorological station, in particular - about amount of
solar and wind energy for each hour of day.

Note that the first line of the datafile is neither data entry, nor header. It is a line
describing the data source. You should extract the name of the station from it.

The data should be returned as a list of lists (not dictionaries).
You can use the csv modules "reader" method to get data in such format.
Another useful method is next() - to get the next line from the iterator.
You should only change the parse_file function.
"""
import csv
import os

DATADIR = ""
DATAFILE = "745090.csv"


def parse_file(datafile):
    name = ""
    data = []
    with open(datafile,'rb') as f:
        firstline = f.readline().split(',')
        name = firstline[1]
        header = f.readline().split(',')
        for line in f:
            fields = line.split(',')
            line_list = ()
            for value in fields:
                line_list.append(value.strip())
            data.append(line_list)
    # Do not change the line below
    return (name, data)


def test():
    datafile = os.path.join(DATADIR, DATAFILE)
    name, data = parse_file(datafile)

    assert name == "MOUNTAIN VIEW MOFFETT FLD NAS"
    assert data[0][1] == "01:00"
    assert data[2][0] == "01/01/2005"
    assert data[2][5] == "2"


if __name__ == "__main__":
    test()
